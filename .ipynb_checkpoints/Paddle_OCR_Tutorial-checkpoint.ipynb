# %% [markdown]
# # 1. Install and Import Dependencies

# %%
# # GitHub repo installation of paddle
 
pip install paddlepaddle --user
pip install paddlepaddle-gpu==2.2.0 --user
pip install paddleocr --user
# !python3 -m pip install paddlepaddle-gpu== 2.3.1 -f https://paddlepaddle.org.cn/whl/stable/noavx.html
# Out:
# ...
#      ---------------------------------------- 7.3/7.3 MB 2.5 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): still running...
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Failed to build numpy
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
#   error: subprocess-exited-with-error
#
# ...
#   exit code: 1
#
#   [807 lines of output]
#   setup.py:67: RuntimeWarning: NumPy 1.19.3 may not yet support Python 3.10.
#     warnings.warn(
#   Running from numpy source directory.
# ...

# %%
# Install paddle OCR
# !pip install paddleocr
# Out:
# ...
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)

# %%
# Clone paddle OCR repo - get FONTS for visualization
# !git clone https://github.com/PaddlePaddle/PaddleOCR
# Out:
# fatal: destination path 'PaddleOCR' already exists and is not an empty directory.

# %%
from paddleocr import PaddleOCR, draw_ocr # main OCR dependencies
from matplotlib import pyplot as plt # plot images
import cv2 #opencv
import os # folder directory navigation

# %% [markdown]
# # 2. Instantiate Model and Detect

# %%
# Setup model
ocr_model = PaddleOCR(lang='en')
# Out:
# [2022/09/01 13:44:02] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=True, use_xpu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, shape_info_filename=None, precision='fp32', gpu_mem=500, image_dir=None, det_algorithm='DB', det_model_dir='C:\\Users\\ssk/.paddleocr/whl\\det\\en\\en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_sast_polygon=False, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_box_type='quad', det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, det_fce_box_type='poly', rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\ssk/.paddleocr/whl\\rec\\en\\en_PP-OCRv3_rec_infer', rec_image_shape='3, 48, 320', rec_batch_num=
# ...

# %%
import urllib.request

img_path=urllib.request.urlretrieve("https://images.ctfassets.net/yadj1kx9rmg0/wtrHxeu3zEoEce2MokCSi/cf6f68efdcf625fdc060607df0f3baef/quwowooybuqbl6ntboz3.jpg", "local-filename.jpg")

# %%
# Run the ocr method on the ocr model
result = ocr_model.ocr("local-filename.jpg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 2>()
#       1 # Run the ocr method on the ocr model
# ----> 2 result = ocr_model.ocr("local-filename.jpg")
#
# NameError: name 'ocr_model' is not defined

# %%
result
# Out:
# [[[[229.0, 459.0], [975.0, 459.0], [975.0, 601.0], [229.0, 601.0]],
#   ('TECHIT', 0.9360291957855225)],
#  [[[96.0, 660.0], [1105.0, 660.0], [1105.0, 805.0], [96.0, 805.0]],
#   ('SERVICES', 0.9550506472587585)]]

# %%
for res in result:
    print(res[1][0])
# Out:
# TECHIT
# SERVICES

# %% [markdown]
# # 3. Visualise Results

# %%
# Extracting detected components
boxes = [res[0] for res in result] 
texts = [res[1][0] for res in result]
scores = [res[1][1] for res in result]

# %%
# Specifying font path for draw_ocr method
font_path = os.path.join('PaddleOCR', 'doc', 'fonts', 'latin.ttf')

# %%
# Import our image - drug 1/2/3
# imports image
img = cv2.imread(img_path) 

# reorders the color channels
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
# Visualize our image and detections
# resizing display area
plt.figure(figsize=(15,15))

# draw annotations on image
annotated = draw_ocr(img, boxes, texts, scores, font_path=font_path) 

# show the image using matplotlib
plt.imshow(annotated)

# %%
img.shape
# Out:
# (400, 800, 3)
